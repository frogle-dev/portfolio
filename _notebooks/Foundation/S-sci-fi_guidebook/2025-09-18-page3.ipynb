# %% [markdown]
# ---
# layout: post
# data: tools
# title: Sci-Fi Guidebook Page 3
# description: Page 3 of Guidebook
# permalink: /sci-fi/page3
# ---

# %% [markdown]
# <style>
# 	body {
# 		background-image: url('{{site.baseurl}}/images/tools/sci-fi-tool/simplistic_background.gif');
# 		background-repeat: no-repeat;
# 		background-attachment: fixed;
# 		background-size: 100% 100%;
# 	}
# </style>
#
# <h2 style="color: black !important;">Deploy</h2>
#
# When you want to finally make a release of your website you can't use make. Instead, you have to deploy your website. <br/>
# There are a few ways to deploy websites, but a good free option is github pages. <br/><br/>
#
# <u><b>Steps to deploy on Github Pages:</b></u>
# <ol>
# 	<li>Create a github repository</li>
# 	<li>Clone the repository onto your system</li>
#     <li>Create all of your website's files in this repository, or copy your existing files into it</li>
#     <li>Go to your repository's settings and enable Github Pages</li>
# 	<li>Now you can either deploy your site using the current branch, or with github actions</li>
# 	<li>With Github Actions you can have your website deployed with Jekyll each time you commit to it</li>
# 	<li>Once the site is deployed</li>
# 		<ol>
# 			<li>Go to the "Pages" section of the repo's settings</li>
# 			<li>Click on your deployed website's link</li>
# 		</ol>
# </ol>
# <br/><br/>
#
# <img src="{{site.baseurl}}/images/tools/sci-fi-tool/github_deploy.png" alt="Github Pages Deploy">
# <br/><br/>
#
# Now you have succesfully set up your website and you can distribute the link to your deployed version to whoever you want to use your website.
# <br/><br/>
#
#
# <h4><b>Learn deploying</b></h4>
#
# <br/>
# <div class="not_deploy">
# 	<p>What shouldn't you use to deploy? All lowercase and one word</p>
# 	<input type="text" id="not_deploy" placeholder="Command:" />
# 	<button class="validate-btn" onclick="validateQuestion('not_deploy', 'not_deploy_status', 'make')">Check answer</button>
# 	<b><div id="not_deploy_status" class="status" style="display: none;"></div></b>
# </div>
# <br/><br/>
#
# <div class="github_pages">
# 	<p>What is a good and free tool for deploying your websites? All lowercase</p>
# 	<input type="text" id="github_pages" placeholder="Command:" />
# 	<button class="validate-btn" onclick="validateQuestion('github_pages', 'github_pages_status', 'github pages')">Check answer</button>
# 	<b><div id="github_pages_status" class="status" style="display: none;"></div></b>
# </div>
# <br/><br/>
#
# <div class="deploy_when">
# 	<p>
# 		When should you deploy your website? Type only the number:<br/>
# 		<ol>
# 			<li>To test your changes every time you commit</li>
# 			<li>To make a release of your website to distribute</li>
# 			<li>To run your website locally</li>
# 		</ol>
# 	</p>
# 	<input type="text" id="deploy_when" placeholder="Command:" />
# 	<button class="validate-btn" onclick="validateQuestion('deploy_when', 'deploy_when_status', '2')">Check answer</button>
# 	<b><div id="deploy_when_status" class="status" style="display: none;"></div></b>
# </div>
# <br/><br/>
#
# <details>
# <summary><b>Answer Key</b></summary>
# <p>
# 	<ul>
# 		<li>1. make</li>
# 		<li>2. github pages</li>
# 		<li>3. 2</li>
# 	</ul>
# </p>
# </details>
# <br/><br/>
# <button type="button" onclick="window.location.href='{{site.baseurl}}/sci-fi/page2';" style="border: 4px solid orange; background-color: #007bff; padding: 15px 30px; cursor:pointer;">
# Previous Page
# </button><br/><br/>
# <button type="button" onclick="window.location.href='{{site.baseurl}}/sci-fi/page4';" style="border: 4px solid orange; background-color: #007bff; padding: 15px 30px; cursor:pointer;">
# Next Page
# </button>
#
#
# <script>
# 	function showStatus(elementId, type, message) {
# 		const statusElement = document.getElementById(elementId);
# 		statusElement.className = `status ${type}`;
# 		statusElement.textContent = message;
# 		statusElement.style.display = 'block';
# 	}
#
# 	function validateQuestion(inputId, statusId, answer) {
# 		const check = document.getElementById(inputId).value.trim();
# 		if (!check) {
# 			showStatus(statusId, 'error', 'Please enter a command');
# 			return;
# 		}
#
# 		if (check == answer)
# 		{
# 			showStatus(statusId, 'correct', 'Correct!');
# 		}
# 		else
# 		{
# 			showStatus(statusId, 'wrong', 'Wrong, try again.');
# 		}
# 	}
# </script>
